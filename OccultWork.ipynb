# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate a random number for divination

# %%
random_number = np.random.randint(1, 100)
print(f"Your divination number is: {random_number}")
# Out:
# Your divination number is: 7

# %%
# Generate random data points for sigil creation

# %%
x = np.random.rand(10)

# %%
y = np.random.rand(10)

# %%
# Create a scatter plot as a digital sigil

# %%
plt.title("Your Digital Sigil")
# Out:
# Text(0.5, 1.0, 'Your Digital Sigil')

# %%
plt.scatter(x, y)

# %%
plt.title("Your Digital Sigil")
# Out:
# Text(0.5, 1.0, 'Your Digital Sigil')

# %%
plt.show()
